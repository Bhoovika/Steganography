# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Preprocessing

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image
from IPython.display import Image

# %% [markdown]
# Input image of size = (1500 x 1500 x 3)

# %%
img = cv2.imread('/content/drive/MyDrive/image/image_rgb/cat.jpg')
m, n, c = img.shape
print(m,n,c)


# pre-process the image
P = np.zeros((m, n, c), dtype=np.uint8)
for i in range(m):
    for j in range(n):
        P[i, j, 0] = int(img[i, j, 0] & 0b11100000) # red channel
        P[i, j, 1] = int(img[i, j, 1] & 0b11100000) # green channel
        P[i, j, 2] = int(img[i, j, 2] & 0b11100000) # blue channel

cv2.imwrite('/content/drive/MyDrive/image/image_rgb/preprocessed_image_rgb.jpg', P)
Image(filename='/content/drive/MyDrive/image/image_rgb/preprocessed_image_rgb.jpg', width=350, height=350)
# Out:
# 1500 1500 3

# %% [markdown]
# #Edge detection-HED

# %%
def edge_detection(image):
  img = cv2.imread("/content/drive/MyDrive/image/image_rgb/" +image +".jpg")


  class CropLayer(object):
    def __init__(self, params, blobs):
        self.startX = 0
        self.startY = 0
        self.endX = 0
        self.endY = 0

    def getMemoryShapes(self, inputs):
        (inputShape, targetShape) = (inputs[0], inputs[1])
        (batchSize, numChannels) = (inputShape[0], inputShape[1])
        (H, W) = (targetShape[2], targetShape[3])

        # compute the starting and ending crop coordinates
        self.startX = int((inputShape[3] - targetShape[3]) / 2)
        self.startY = int((inputShape[2] - targetShape[2]) / 2)
        self.endX = self.startX + W
        self.endY = self.startY + H

        return [[batchSize, numChannels, H, W]]

    def forward(self, inputs):
        return [inputs[0][:, :, self.startY:self.endY,
                self.startX:self.endX]]
  
  protoPath = "/content/drive/MyDrive/image/deploy.prototxt.txt"
  modelPath = "/content/drive/MyDrive/image/hed_pretrained_bsds.caffemodel"
  net = cv2.dnn.readNetFromCaffe(protoPath, modelPath)

  cv2.dnn_registerLayer("Crop", CropLayer)
  img = cv2.imread("/content/drive/MyDrive/image/image_rgb/" +image +".jpg")
  plt.imshow(img)
  (H, W) = img.shape[:2]

  mean_pixel_values= np.average(img, axis = (0,1))
  blob = cv2.dnn.blobFromImage(img, scalefactor=0.7, size=(W, H),
                              mean=(mean_pixel_values[0], mean_pixel_values[1], mean_pixel_values[2]),
                              swapRB= False, crop=False)

  blob_for_plot = np.moveaxis(blob[0,:,:,:], 0,2)
  plt.imshow(blob_for_plot)

  net.setInput(blob)
  hed = net.forward()
  hed = hed[0,0,:,:] 
  hed = (255 * hed).astype("uint8")  

  plt.title("HED " +image)
  cv2.imwrite('/content/drive/MyDrive/image/image_rgb/HED '+image+'.jpg', hed)
  m,n=hed.shape
  print(m,n)
  plt.imshow(hed,cmap='gray')

# %%
edge_detection("preprocessed_image_rgb")
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1500 1500

# %% [markdown]
# #Binarization

# %%
img = cv2.imread('/content/drive/MyDrive/image/image_rgb/HED preprocessed_image_rgb.jpg', 0) 

#Otsu's thresholding
otsu_thresh, otsu = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

#hard thresholding
hard_thresh = 127
hard = cv2.threshold(img, hard_thresh, 255, cv2.THRESH_BINARY)[1]

#mean adaptive thresholding
mean_block_size = 11
mean_c = 2
mean = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, mean_block_size, mean_c)

#Gaussian adaptive thresholding
gaussian_block_size = 11
gaussian_c = 2
gaussian = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, gaussian_block_size, gaussian_c)

plt.imshow(otsu)
plt.title('Otsu thresholding')
plt.show()
plt.imshow(hard)
plt.title('Hard thresholding')
plt.show()
plt.imshow(mean)
plt.title('Mean adaptive thresholding')
plt.show()
plt.imshow(gaussian)
plt.title('Gaussian adaptive thresholding')
plt.show()
cv2.imwrite('/content/drive/MyDrive/image/image_rgb/otsu_thresholded.jpg', otsu)
cv2.imwrite('/content/drive/MyDrive/image/image_rgb/hard_thresholded.jpg', hard)
cv2.imwrite('/content/drive/MyDrive/image/image_rgb/mean_thresholded.jpg', mean)
cv2.imwrite('/content/drive/MyDrive/image/image_rgb/gaussian_thresholded.jpg', gaussian)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ##No.of.edges

# %%
CI = cv2.imread('/content/drive/MyDrive/image/image_rgb/cat.jpg', cv2.IMREAD_COLOR)
RI = cv2.imread('/content/drive/MyDrive/image/image_rgb/otsu_thresholded.jpg',0)
count=0
for i in range(CI.shape[0]):
    for j in range(CI.shape[1]):
        if (RI[i,j] == 255):
          count+=1
print(count)
# Out:
# 660635

# %%
CI = cv2.imread('/content/drive/MyDrive/image/image_rgb/cat.jpg', cv2.IMREAD_COLOR)
RI = cv2.imread('/content/drive/MyDrive/image/image_rgb/hard_thresholded.jpg',0)
count=0 
for i in range(CI.shape[0]):
    for j in range(CI.shape[1]):
        if (RI[i,j] == 255):
          count+=1
print(count)
# Out:
# 185788

# %%
CI = cv2.imread('/content/drive/MyDrive/image/image_rgb/cat.jpg', cv2.IMREAD_COLOR)
RI = cv2.imread('/content/drive/MyDrive/image/image_rgb/mean_thresholded.jpg',0)
count=0  
for i in range(CI.shape[0]):
    for j in range(CI.shape[1]):
        if (RI[i,j] == 255):
          count+=1
print(count)
# Out:
# 807123

# %%
CI = cv2.imread('/content/drive/MyDrive/image/image_rgb/cat.jpg', cv2.IMREAD_COLOR)
RI = cv2.imread('/content/drive/MyDrive/image/image_rgb/gaussian_thresholded.jpg',0)
count=0  
for i in range(CI.shape[0]):
    for j in range(CI.shape[1]):
        if (RI[i,j] == 255):
          count+=1
print(count)
# Out:
# 952832

# %% [markdown]
# #RGB

# %% [markdown]
# Embedding

# %%
N = 952832
x = 2
y = 1
R = 1500
C = 1500
b = 8
a = (R*C*y)+N*(x-y)
c = a/b
d = np.sqrt(c)
print("size of the secret image: ",int(d))
# Out:
# size of the secret image:  632

# %%
CI = cv2.imread('/content/drive/MyDrive/image/image_rgb/cat.jpg', cv2.IMREAD_COLOR)
SEI = cv2.imread('/content/drive/MyDrive/image/image_rgb_1/secret_image.jpg',cv2.IMREAD_COLOR)
RI = cv2.imread('/content/drive/MyDrive/image/image_rgb/gaussian_thresholded.jpg',0)

# Convert secret image into 1D bitstream
s_1 = np.array(SEI.flatten(), np.uint8)
s = np.unpackbits(SEI)


SI_prime = np.zeros_like(CI)
SI_prime[:] = CI


x = 2   # Number of bits to embed in edge pixels
y = 1   # Number of bits to embed in non-edge pixels


for i in range(CI.shape[0]):
    for j in range(CI.shape[1]):
          #Create a random index
          index = np.random.randint(0, 4, 1)[0]
          binary_str = format(index, '02b')
          bits = [int(bit) for bit in binary_str]
          #place the random index value on channel 'R'
          for m in range(0,2):
              bit = bits[0]
              SI_prime[i,j,0]&= ~(1 << m) 
              SI_prime[i,j,0]|= (bit << m)
              bits = np.delete(bits, 0)
          #check the edge
          if (RI[i,j] == 255):     
              for k in range(1,3):
                      if len(s) < x:
                          break
                      for l in range(index,x+index):
                          if len(s) ==0:
                            break
                          bit = s[0]
                          SI_prime[i,j,k]&= ~(1 << l)
                          SI_prime[i,j,k]|= (bit << l)
                          s = np.delete(s, 0)
                          if len(s) == 0:
                              break              
          else:
                    for k in range(1,3):
                      if len(s) < x:
                          break
                      for l in range(index,y+index):
                          if len(s) ==0:
                            break
                          bit = s[0]
                          SI_prime[i,j,k]&= ~(1 << l) 
                          SI_prime[i,j,k]|= (bit << l)
                          s = np.delete(s, 0)
                          if len(s) == 0:
                              break
          if len(s) == 0:
              break
    if len(s) == 0:
          break

np.save('/content/drive/MyDrive/image/image_rgb/my_array.npy', SI_prime)
cv2.imwrite('/content/drive/MyDrive/image/image_rgb/stego_image_opt.jpg', SI_prime)
# Out:
# True

# %%
import random

def Pixel_Adjustment(pixel):
    return tuple(min(255, max(0, int(c + random.uniform(-10, 10)))) for c in pixel)

secret_image = np.zeros_like(SI_prime)

for i in range(SI_prime.shape[0]):
    for j in range(SI_prime.shape[1]):
        r, g, b = SI_prime[i][j]
        r_new, g_new, b_new = Pixel_Adjustment((r, g, b))
        secret_image[i][j] = (r_new, g_new, b_new)

cv2.imwrite('/content/drive/MyDrive/image/image_rgb/stego_image_opt_new.jpg', secret_image)
# Out:
# True

# %% [markdown]
# Encryption and decryption

# %%
# Define the prime modulus and base
p = 23
g = 5

# a, b- private key
# A, B - public key
a = 6
A = (g ** a) % p


b = 15
B = (g ** b) % p

shared_secret_a = (B ** a) % p
shared_secret_b = (A ** b) % p

assert shared_secret_a == shared_secret_b

# %%
x = '2'
m = int(x)

encrypted_message = m ^ shared_secret_a

print(f'Original message: {x}')
print(f'Encrypted message: {encrypted_message}')
# Out:
# Original message: 2
# Encrypted message: 0

# %%
decrypted_message = encrypted_message ^ shared_secret_b
decrypted_message_str_x = str(decrypted_message)
print(f'Decrypted message: {decrypted_message_str_x}')
# Out:
# Decrypted message: 2

# %%
y= '1'
m = int(y)

#XOR with the shared secret key
encrypted_message = m ^ shared_secret_a
print(f'Original message: {y}')
print(f'Encrypted message: {encrypted_message}')
# Out:
# Original message: 1
# Encrypted message: 3

# %%
decrypted_message = encrypted_message ^ shared_secret_b
decrypted_message_str_y = str(decrypted_message)
print(f'Decrypted message: {decrypted_message_str_y}')
# Out:
# Decrypted message: 1

# %% [markdown]
# Extraction

# %%
#a=240000 #100
#a=960000 #200
#a=2160000 #300
#a=3840000 #400
a=6000000 #500
#a=8640000 #600
CI = cv2.imread('/content/drive/MyDrive/image/image_rgb/cat.jpg', cv2.IMREAD_COLOR)
SI = cv2.imread('/content/drive/MyDrive/image/image_rgb/stego_image_opt.jpg', cv2.IMREAD_COLOR)
RI = cv2.imread('/content/drive/MyDrive/image/image_rgb/gaussian_thresholded.jpg', 0)

secret=[]
indices=[]
x = decrypted_message_str_x   # Number of bits to extract in edge pixels
y = decrypted_message_str_y   # Number of bits to extract in non-edge pixels


for i in range(CI.shape[0]):
    for j in range(CI.shape[1]):
        indices.clear()
        for m in range(0,2):
            bit=(SI_prime[i,j,0] & (1 << m)) >> m
            indices.append(bit)
        my_string = ''.join(map(str, indices))
        decimal_num = int(my_string, 2)
        
        if (RI[i,j] == 255):
              for k in range(1,3):
                  for l in range(int(decimal_num),int(x)+int(decimal_num)):
                    s=(SI_prime[i,j,k] & (1 << l)) >> l
                    secret.append(s)
                    if len(secret)==a:
                        break
                  if len(secret)==a:
                        break
            
        else:
          for k in range(1,3):
            for l in range(int(decimal_num),int(y)+int(decimal_num)):
                  s=(SI_prime[i,j,k] & (1 << l)) >> l
                  secret.append(s)
                  if len(secret)==a:
                      break
            if len(secret)==a:
                  break
           
        if len(secret)==a:
            break
    if len(secret)==a:
            break    
packed = []
for i in range(0, len(secret), 8):
    byte = secret[i:i+8]
    packed.append(int(''.join(map(str, byte)), 2))

arr1 = np.array(packed, np.uint8)
arr_2d = arr1.reshape((500,500,3))

# %%
from PIL import Image
import numpy as np
import cv2
img1=cv2.cvtColor(arr_2d, cv2.COLOR_BGR2RGB)
img=Image.fromarray(img1)
img.save('/content/drive/MyDrive/image/image_rgb/secret.jpg')

# %%
from IPython.display import Image
Image(filename='/content/drive/MyDrive/image/image_rgb/secret.jpg', width=300, height=300)

# %% [markdown]
# #Performance metrics

# %% [markdown]
# ### PSNR

# %%
MSE = np.mean((CI - SI_prime)**2)
PSNR = 20 * np.log10(255 / np.sqrt(MSE))
psnr = PSNR.item()
print("PSNR= {:.2f}".format(psnr))
# Out:
# PSNR= 41.86

# %% [markdown]
# ### SSIM

# %%
from PIL import Image
import numpy as np
image1 = np.array(Image.open('/content/drive/MyDrive/image/image_rgb/cat.jpg'))
image2 = np.array(Image.open('/content/drive/MyDrive/image/image_rgb/stego_image_opt.jpg'))

# Calculate the mean and standard deviation of each image
mean1 = np.mean(image1)
std1 = np.std(image1)
mean2 = np.mean(image2)
std2 = np.std(image2)

print('Image 1 - Mean: {}, Std: {}'.format(mean1, std1))
print('Image 2 - Mean: {}, Std: {}'.format(mean2, std2))
# Out:
# Image 1 - Mean: 118.8060402962963, Std: 59.298314495470365
# Image 2 - Mean: 118.70942577777778, Std: 59.362653390699656

# %%
I1 = np.array(Image.open('/content/drive/MyDrive/image/image_rgb/cat.jpg'))
I2 = np.array(Image.open('/content/drive/MyDrive/image/image_rgb/stego_image_opt.jpg'))

mean_I1 = np.mean(I1)
mean_I2 = np.mean(I2)

I1_d = I1 - mean_I1
I2_d = I2 - mean_I2

covariance = np.mean(I1_d * I2_d)

print('Covariance :', covariance)
# Out:
# Covariance : 3511.6181841618086

# %%
α = β = γ = 1.0

k1 = 0.01 
k2 = 0.03
L = 255
C1 = (int)(k1 * L)**2
C2 = (int)(k2 * L)**2
C3 = C2 // 2

l = (2 * mean1*mean2 + C1)/(mean1**2 + mean2**2 + C1)
c = (2*std1*std2 + C2)/(std1**2 + std2**2 + C2)
s = (covariance + C3)/(std1*std2 + C3)

SSIM = (l**α) * (c**β) * (s**γ)
print("Similarity index= ",(SSIM))
# Out:
# Similarity index=  0.9976043769724773

# %%
R = 1500 
C = 1500 
x = 2
y = 1
N = 952832
a = (1- N/(R*C))*y
b = (N/(R*C)) * x
c = a+b
print("payload for 1 channel = {:.2f}".format(c))
a = (1- N/(R*C*3))*y
b = (N/(R*C)) * x
c = a+b
print("payload for 3 channels = {:.2f}".format(c))
# Out:
# payload for 1 channel = 1.42
# payload for 3 channels = 1.71

# %%
original_image = cv2.imread('/content/drive/MyDrive/image/image_rgb/cat.jpg')
stego_image = cv2.imread('/content/drive/MyDrive/image/image_rgb/stego_image_opt.jpg')

# Calculate histograms
original_hist, _ = np.histogram(original_image, bins=256, range=(0, 255))
stego_hist, _ = np.histogram(stego_image, bins=256, range=(0, 255))

# Normalize histograms
original_hist_sum = np.sum(original_hist)
stego_hist_sum = np.sum(stego_hist)

if original_hist_sum == 0:
    original_hist_norm = np.zeros_like(original_hist)
else:
    original_hist_norm = original_hist / original_hist_sum

if stego_hist_sum == 0:
    stego_hist_norm = np.zeros_like(stego_hist)
else:
    stego_hist_norm = stego_hist / stego_hist_sum

# Calculate chi-square distance
chi_square_dist = np.sum(np.divide(np.square(original_hist_norm - stego_hist_norm), original_hist_norm))

print("chi= {:.2f}".format(chi_square_dist))
# Out:
# chi= 0.03

# %%
import cv2

# Load the images
cover_image = cv2.imread('/content/drive/MyDrive/image/image_rgb/cat.jpg')
secret_image = cv2.imread('/content/drive/MyDrive/image/image_rgb/stego_image_opt.jpg')


# Convert the images to grayscale
gray1 = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
gray2 = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)

# Compute the histograms for each channel
hist1_r = cv2.calcHist([image1], [0], None, [256], [0, 256])
hist1_g = cv2.calcHist([image1], [1], None, [256], [0, 256])
hist1_b = cv2.calcHist([image1], [2], None, [256], [0, 256])

hist2_r = cv2.calcHist([image2], [0], None, [256], [0, 256])
hist2_g = cv2.calcHist([image2], [1], None, [256], [0, 256])
hist2_b = cv2.calcHist([image2], [2], None, [256], [0, 256])

# Normalize the histograms
cv2.normalize(hist1_r, hist1_r, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX)
cv2.normalize(hist1_g, hist1_g, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX)
cv2.normalize(hist1_b, hist1_b, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX)

cv2.normalize(hist2_r, hist2_r, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX)
cv2.normalize(hist2_g, hist2_g, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX)
cv2.normalize(hist2_b, hist2_b, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX)

# Compute the correlation coefficients
corr_r = cv2.compareHist(hist1_r, hist2_r, cv2.HISTCMP_CORREL)
corr_g = cv2.compareHist(hist1_g, hist2_g, cv2.HISTCMP_CORREL)
corr_b = cv2.compareHist(hist1_b, hist2_b, cv2.HISTCMP_CORREL)

# Compute the average correlation coefficient
score = (corr_r + corr_g + corr_b) / 3

print('Histogram similarity score: {:.2f}'.format(score))
# Out:
# Histogram similarity score: 0.97
